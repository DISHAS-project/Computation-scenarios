# %%
#Initial environement of computations

import matplotlib.pyplot as plt
import numpy as np
from kanon.calendars import Calendar, Date
from kanon.calendars.calendars import float_to_hm, hm_to_float
from kanon.tables import HTable
from kanon.units import Sexagesimal, Historical
from kanon.units.precision import set_precision, TruncatureMode, PrecisionMode
import astropy.units as u


from kanon.tables.htable_reader import (
    DISHAS_REQUEST_URL,
    read_historical,
    read_sexag_array,
    read_intsexag_array,
)
from kanon.tables import HTable
import requests


number_reader = {
    "sexagesimal": read_sexag_array,
    "floating sexagesimal": read_sexag_array,
    "integer and sexagesimal": read_intsexag_array,
    "historical": read_historical,
}

# %%
#Initial table set

#Mars
Equation_center=HTable.read(187)
Equation_anomaly=HTable.read(188)
Anomaly_maxdist=HTable.read(247)
Anomaly_mindist=HTable.read(248)
Min_prop=HTable.read(249)
Target_equation=HTable.read(1362)

# %%
# Formating and initialising the Test tables

Hist_table=Target_equation.copy()
Test_recomp=Target_equation.copy()
Delta_recomp=Target_equation.copy()
for i in range(60):
    for j in range(41):
        Test_recomp[i][1][j][1]=Sexagesimal('0;')*u.degree
        Delta_recomp[i][1][j][1]=Sexagesimal('0;')*u.degree

# %%
for i in range(60):
    with set_precision(tmode=TruncatureMode.TRUNC, pmode=2):
        # Initial values for mean center 
        mean_center= Hist_table[i][0]*u.degree
                        
        # computation of the equation of center
        eq_center=Equation_center.get(mean_center)
            
    for j in range(41):
        with set_precision(tmode=TruncatureMode.TRUNC, pmode=2):

            # Initial values for mean argument
            mean_argument= Hist_table[0][1][j][0]*u.degree

            # Computation of the true argument
            true_argument=mean_argument-eq_center   

            # Computation of the true center
            true_center= mean_center+eq_center

            # computation of the first equation of anomaly
            eq_anomaly1=Equation_anomaly.get(true_argument)

            #correction of the equation of anomaly with the minuta proportionalia and diversity of diameter
            min_prop=Min_prop.get(true_center)
            if min_prop<=0:
                div_diam=Anomaly_maxdist.get(true_argument)
                prop_part_anomaly=div_diam*min_prop/(60*u.degree)
                eq_anomaly2=eq_anomaly1+prop_part_anomaly
            else:
                div_diam=Anomaly_mindist.get(true_argument)
                prop_part_anomaly=div_diam*min_prop/(60*u.degree)
                eq_anomaly2=eq_anomaly1+prop_part_anomaly

        # computation of the total equation
        with set_precision(tmode=TruncatureMode.ROUND, pmode=1):
            eq_total=eq_center+eq_anomaly2
            Test_recomp[i][1][j][1]=eq_total
            Delta_recomp[i][1][j][1]=60*(Hist_table.get(mean_center.value).get(mean_argument.value)-eq_total)/u.degree

# %%
# residuals visualisation and statistical summaries 1
A=Delta_recomp.to_pandas()
(A.mean().mean(), A.std().std())
# Out:
# (-0.02926829268292699, 25.993382489036314)

# %%
# residuals visualisation and statistical summaries 2
A.astype(float).style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T
, #T_ed24e_row2_col30, #T_ed24e_row2_col31, #T_ed24e_row2_col32, #T_ed24e_row2_col33, #T_ed24e_row2_col34, #T_ed24e_row2_col35, #T_ed24e_row2_col36, #T_ed24e_row2_col38, #T_ed24e_row2_col39, #T_ed24e_row2_col40, #T_ed24e_row2_col41, #T_ed24e_row2_col42, #T_ed24e_row2_col43, #T_ed24e_row2_col44, #T_ed24e_row2_col45, #T_ed24e_row2_col46, #T_ed24e_row2_col47, #T_ed24e_row2_col48, #T_ed24e_row2_col49, #T_ed24e_row2_col50, #T_ed24e_row2_col51, #T_ed24e_row2_col52, #T_ed24e_row2_col53, #T_ed24e_row2_col54, #T_ed24e_row2_col55, #T_ed24e_row2_col56, #T_ed24e_row2_col57, #T_ed24e_row2_col58, #T_ed24e_row2_col59, #T_ed24e_row3_col1, #T_ed24e_row3_col2, #T_ed24e_row3_col3, #T_ed24e_row3_col4, #T_ed24e_row3_col5, #T_ed24e_row3_col6, #T_ed24e_row3_col7, #T_ed24e_row3_col8, #T_ed24e_row3_col9, #T_ed24e_row3_col10, #T_ed24e_row3_col11, #T_ed24e_row3_col12, #T_ed24e_row3_col14, #T_ed24e_row3_col15, #T_ed24e_row3_col17, #T_ed24e_row3_col18, #T_ed24e_row3_col19, #T_ed24e_row3_col20, #T_ed24e_row3_col21, #T_ed24e_row3_col22, #T_ed24e_row3_col23, #T_ed24e_row3_col24, #T_ed24e_row3_col25, #T_ed24e_row3_col26, #T_ed24e_row3_col27, #T_ed24e_row3_col28, #T_ed24e_row3_col29, #T_ed24e_row3_col30, #T_ed24e_row3_col31, #T_ed24e_row3_col32, #T_ed24e_row3_col33, #T_ed24e_row3_col34, #T_ed24e_row3_col35, #T_ed24e_row3_col36, #T_ed24e_row3_col37, #T_ed24e_row3_col38, #T_ed24e_row3_col39, #T_ed24e_row3_col40, #T_ed24e_row3_col41, #T_ed24e_row3_col42, #T_ed24e_row3_col43, #T_ed24e_row3_col44, #T_ed24e_row3_col46, #T_ed24e_row3_col47, #T_ed24e_row3_col48, #T_ed24e_row3_col49, #T_ed24e_row3_col50, #T_ed24e_row3_col51, #T_ed24e_row3_col52, #T_ed24e_row3_col53, #T_ed24e_row3_col54, #T_ed24e_row3_col55, #T_ed24e_row3_col56, #T_ed24e_row3_col57, #T_ed24e_row3_col58, #T_ed24e_row4_col0, #T_ed24e_row4_col1, #T_ed24e_row4_col2, #T_ed24e_row4_col3, #T_ed24e_row4_col4, #T_ed24e_row4_col5, #T_ed24e_row4_col6, #T_ed24e_ro ...

# %%
#csv export of the recomputed table
B=Test_recomp.to_pandas()
compression_opts = dict(method='zip',archive_name='Mars_eq_TM.csv')
B.to_csv('Mars_eq_TM.zip', index=False, compression=compression_opts)
