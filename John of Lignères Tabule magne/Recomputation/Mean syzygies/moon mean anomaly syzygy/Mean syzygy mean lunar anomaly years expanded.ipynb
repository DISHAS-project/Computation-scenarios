# %%
#Initial environement of computations


import matplotlib.pyplot as plt
import numpy as np
from kanon.calendars import Calendar, Date
from kanon.calendars.calendars import float_to_hm, hm_to_float
from kanon.tables import HTable
from kanon.units import Sexagesimal, Historical
from kanon.units.precision import set_precision, TruncatureMode, PrecisionMode
import astropy.units as u


from kanon.tables.htable_reader import (
    DISHAS_REQUEST_URL,
    read_historical,
    read_sexag_array,
    read_intsexag_array,
)
from kanon.tables import HTable
import requests

from kanon.units import Sexagesimal, Historical, IntegerAndSexagesimal, Temporal
from kanon.calendars import*

Cal=julian_ad = Calendar.registry["Julian A.D."]

number_reader = {
    "sexagesimal": read_sexag_array,
    "floating sexagesimal": read_sexag_array,
    "integer and sexagesimal": read_intsexag_array,
    "historical": read_historical,
}

# %%
#Initial table set

# Historical target table
Hist_table=HTable.read(582, with_units=False)
Hist_table
# Out:
# <HTable length=23>
#         Years            Entries
# IntegerAndSexagesimal   Historical
# --------------------- --------------
#                365 ;  10s 09 ; 48,07
#                730 ;  08s 19 ; 36,14
#               1095 ;  07s 25 ; 13,22
#               1461 ;  06s 05 ; 01,29
#               1826 ;  04s 14 ; 49,36
#               2191 ;  03s 20 ; 26,43
#               2556 ;  02s 00 ; 14,50
#               2922 ;      10 ; 02,57
#               3287 ;  11s 15 ; 40,05
#               3652 ;  09s 25 ; 28,12
#                   ...            ...
#               5113 ;  04s 26 ; 18,41
#               5478 ;  03s 06 ; 06,48
#               5844 ;  01s 15 ; 54,55
#               6209 ;      21 ; 32,02
#               6574 ;  11s 01 ; 20,09
#               6939 ;  09s 11 ; 08,16
#               7305 ;  08s 16 ; 45,24
#               7670 ;  06s 26 ; 33,31
#               8035 ;  06s 02 ; 10,38
#               8400 ;  04s 11 ; 58,45

# %%
# Formating and initialising the Test tables

Test_recomp=Hist_table.copy()
Delta_recomp=Hist_table.copy()
for i in range(23):
    Test_recomp[i][1]=Historical(Sexagesimal('0;0,0'),2)
    Delta_recomp[i][1]=Historical(Sexagesimal('0;0,0'),2)

# %%
#mean motion parameter from the Parisian Alfonsine Tables
daily_mean_elong=Historical(Sexagesimal("12;11,26,41,37,51,50,39"),8)
daily_mean_moon_anom=Historical(Sexagesimal("13;3,53,57,30,21,4,13"),7)
delta_Paris_Toledo=Temporal("0;0,48")
REVO=Historical(Sexagesimal("6,0;0,0"),8)

# computation of the synodic month in DN

synodic_month=REVO/daily_mean_elong
synodic_month=Temporal(synodic_month,8)
synodic_month=synodic_month.decimal
synodic_month=float(synodic_month)

for i in range(23):
    with set_precision(tmode=TruncatureMode.TRUNC, pmode=8):

        # Computing the mean sun and mean moon for a given number of synodic years
        months=int(Hist_table[i][0]/synodic_month)
        mean_moon_anom=(months*synodic_month*daily_mean_moon_anom)%REVO
                       
        #filling the Test and Delta tables with the final precision
        with set_precision(tmode=TruncatureMode.ROUND, pmode=2):
            Test_recomp[i][1]=1*mean_moon_anom
            Delta_recomp[i][1]=60*60*(Hist_table[i][1]-Test_recomp[i][1])
Test_recomp
# Out:
# <HTable length=23>
#         Years            Entries
# IntegerAndSexagesimal   Historical
# --------------------- --------------
#                365 ;  10s 09 ; 48,07
#                730 ;  08s 19 ; 36,14
#               1095 ;  07s 25 ; 13,22
#               1461 ;  06s 05 ; 01,29
#               1826 ;  04s 14 ; 49,36
#               2191 ;  03s 20 ; 26,43
#               2556 ;  02s 00 ; 14,50
#               2922 ;      10 ; 02,57
#               3287 ;  11s 15 ; 40,05
#               3652 ;  09s 25 ; 28,12
#                   ...            ...
#               5113 ;  04s 26 ; 18,41
#               5478 ;  03s 06 ; 06,48
#               5844 ;  01s 15 ; 54,55
#               6209 ;      21 ; 32,02
#               6574 ;  11s 01 ; 20,09
#               6939 ;  09s 11 ; 08,16
#               7305 ;  08s 16 ; 45,24
#               7670 ;  06s 26 ; 33,31
#               8035 ;  06s 02 ; 10,38
#               8400 ;  04s 11 ; 58,45

# %%
# residuals visualisation and statistical summaries 1
B=Delta_recomp.to_pandas()
(B.mean().mean(), B.std().std())
# Out:
# (0.0, nan)

# %%
B.astype(int).style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_2f810_row0_col0, #T_2f810_row1_col0, #T_2f810_row2_col0, #T_2f810_row3_col0, #T_2f810_row4_col0, #T_2f810_row5_col0, #T_2f810_row6_col0, #T_2f810_row7_col0, #T_2f810_row8_col0, #T_2f810_row9_col0, #T_2f810_row10_col0, #T_2f810_row11_col0, #T_2f810_row12_col0, #T_2f810_row13_col0, #T_2f810_row14_col0, #T_2f810_row15_col0, #T_2f810_row16_col0, #T_2f810_row17_col0, #T_2f810_row18_col0, #T_2f810_row19_col0, #T_2f810_row20_col0, #T_2f810_row21_col0, #T_2f810_row22_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_2f810">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f810_level0_col0" class="col_heading level0 col0" >Entries</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Years</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f810_level0_row0" class="row_heading level0 row0" >365 ; </th>
#       <td id="T_2f810_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row1" class="row_heading level0 row1" >730 ; </th>
#       <td id="T_2f810_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row2" class="row_heading level0 row2" >1095 ; </th>
#       <td id="T_2f810_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row3" class="row_heading level0 row3" >1461 ; </th>
#       <td id="T_2f810_row3_col0" class="data row3 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row4" class="row_heading level0 row4" >1826 ; </th>
#       <td id="T_2f810_row4_col0" class="data row4 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row5" class="row_heading level0 row5" >2191 ; </th>
#       <td id="T_2f810_row5_col0" class="data row5 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row6" class="row_heading level0 row6" >2556 ; </th>
#       <td id="T_2f810_row6_col0" class="data row6 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row7" class="row_heading level0 row7" >2922 ; </th>
#       <td id="T_2f810_row7_col0" class="data row7 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row8" class="row_heading level0 row8" >3287 ; </th>
#       <td id="T_2f810_row8_col0" class="data row8 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row9" class="row_heading level0 row9" >3652 ; </th>
#       <td id="T_2f810_row9_col0" class="data row9 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row10" class="row_heading level0 row10" >4017 ; </th>
#       <td id="T_2f810_row10_col0" class="data row10 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row11" class="row_heading level0 row11" >4383 ; </th>
#       <td id="T_2f810_row11_col0" class="data row11 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row12" class="row_heading level0 row12" >4748 ; </th>
#       <td id="T_2f810_row12_col0" class="data row12 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row13" class="row_heading level0 row13" >5113 ; </th>
#       <td id="T_2f810_row13_col0" class="data row13 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row14" class="row_heading level0 row14" >5478 ; </th>
#       <td id="T_2f810_row14_col0" class="data row14 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row15" class="row_heading level0 row15" >5844 ; </th>
#       <td id="T_2f810_row15_col0" class="data row15 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row16" class="row_heading level0 row16" >6209 ; </th>
#       <td id="T_2f810_row16_col0" class="data row16 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row17" class="row_heading level0 row17" >6574 ; </th>
#       <td id="T_2f810_row17_col0" class="data row17 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row18" class="row_heading level0 row18" >6939 ; </th>
#       <td id="T_2f810_row18_col0" class="data row18 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row19" class="row_heading level0 row19" >7305 ; </th>
#       <td id="T_2f810_row19_col0" class="data row19 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row20" class="row_heading level0 row20" >7670 ; </th>
#       <td id="T_2f810_row20_col0" class="data row20 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row21" class="row_heading level0 row21" >8035 ; </th>
#       <td id="T_2f810_row21_col0" class="data row21 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f810_level0_row22" class="row_heading level0 row22" >8400 ; </th>
#       <td id="T_2f810_row22_col0" class="data row22 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
#csv export of the recomputed table
B=Test_recomp.to_pandas()
compression_opts = dict(method='zip',archive_name='Mean syzygy mean moon years expanded.csv')
B.to_csv('Mean syzygy mean moon years expanded.zip', index=False, compression=compression_opts)
